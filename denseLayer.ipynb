# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruvpathak23/deep-learning/blob/main/denseLayer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dense Layer from Scartch

# %%
import tensorflow as tf
layer = tf.keras.layers.Dense(units = 2)

# %%
class MyDenseLayer(tf.keras.layers.Layer):
  def __init__(self, input_dim, output_dim):
    super(MyDenseLayer,self).__init__()

    # Initialization of weights
    self.w = self.add_weight([input_dim, output_dim])
    self.b = self.add_weight([1,output_dim])

  def call(self, inputs):
    # Forward propagate the inputs
    z = tf.matmul (inputs, self.w) + self.b

    #Feed through a non-linear activation
    output = tf.math.sigmoid(z)
    return output
